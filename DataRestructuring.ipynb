# %% [markdown]
# Will be Restructuring the Data Scraped from the Scrapping Tool

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\Project_Miscellaneous\DA_Project\Naukri_Data\Naukri_Data\Data_Scraping\Naukri_Data_Raw.csv')
headers = ["Job_Title","Company_Name","Job_Ratings","Number_Of_Reviews","Job_Link","Experience_Required","Job_Posted_On","Salary_Range","Job_Location","Skills_Required"]
df.columns=headers

# %%
df.head(20)
# Out:
#                                             Job_Title  \
# 0       Data Analyst - Python/Artificial Intelligence
# 1       Data Analyst - Python/Artificial Intelligence
# 2          Professional - MIS Executive/ Data Analyst
# 3       Sr. Data Analyst (BI) - Adv Excel, VBA-Macros
# 4    Analyst, Data Management & Quantitative Analysis
# 5   Senior Business Data Analyst ( Notice Period: ...
# 6   Urgent Requirement Business Analyst / Data Ana...
# 7          Job Opportunity For Data Analyst Graduates
# 8                                  Sr Data Analyst Il
# 9   Sr. Product Analyst / Sr. Business Analyst / S...
# 10          Urgent Requirement Data Analyst // Cars24
# 11                             Reference Data Analyst
# 12                                Senior Data Analyst
# 13       Business Data Analyst - Modeling & Profiling
# 14  Immediate Openings For Data Analyst Role - Pon...
# 15  Associate/Senior Associate - Data Engineer / D...
# ...

# %%
df.count()
# Out:
# Job_Title              197
# Company_Name           197
# Job_Ratings            143
# Number_Of_Reviews      143
# Job_Link               197
# Experience_Required    195
# Job_Posted_On          197
# Salary_Range           197
# Job_Location           197
# Skills_Required        197
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Job_Title               0
# Company_Name            0
# Job_Ratings            54
# Number_Of_Reviews      54
# Job_Link                0
# Experience_Required     2
# Job_Posted_On           0
# Salary_Range            0
# Job_Location            0
# Skills_Required         0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()
